# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
x=np.arange(0,6)
t=np.arange(0,11)
Z=np.random.random((11,6))

# %%
Z.shape
# Out:
# (11, 6)

# %%
pl.plot(t,Z)
pl.show()

# %%
pl.plot(x,Z.T)
pl.show()

# %%
D=np.array([[1,2,3],[4,5,6]])
print(D)
print(D.T)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 4]
#  [2 5]
#  [3 6]]
